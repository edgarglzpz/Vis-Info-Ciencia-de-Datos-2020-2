# %%
import ipywidgets as widgets
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
import ipywidgets as widgets
from IPython.display import display
from ipywidgets import interactive

# %%
coronapaises = pd.read_excel('prueba.xlsx', delimiter=',')

# %%
coronapaises.head()
# Out:
#               Paises  Casos1  Muertes1  Casos2  Muertes2  Casos3  Muertes3  \
# 0  Republic of Korea    16.0       0.0    18.0       0.0    23.0       0.0
# 1              Japan    20.0       0.0    33.0       0.0    25.0       0.0
# 2          Singapore    18.0       0.0    24.0       0.0    28.0       0.0
# 3           Malaysia    10.0       0.0    10.0       0.0    12.0       0.0
# 4          Australia    12.0       0.0    13.0       0.0    14.0       0.0
#
#    Casos4  Muertes4  Casos5  ...  Casos26  Muertes26  Casos27  Muertes27  \
# 0    24.0       0.0    24.0  ...   3736.0       18.0   4212.0       22.0
# 1    25.0       0.0    25.0  ...    239.0        5.0    254.0        6.0
# 2    30.0       0.0    33.0  ...    102.0        0.0    106.0        0.0
# 3    14.0       0.0    15.0  ...     24.0        0.0     24.0        0.0
# 4    15.0       0.0    15.0  ...     25.0        0.0     27.0        1.0
#
#    Casos28  Muertes28  Casos29  Muertes29  Casos30  Muertes30
# ...

# %%
#numero1=[]
#for i in range(85):
#    numero1.append(1)
#number1= pd.DataFrame(numero1, columns=['Dia'])

#dia1 = coronapaises[['Paises', 'Casos1', 'Muertes1']]
#dia1.columns = ['Paises', 'Casos', 'Muertes']

#numpais1=[]
#for i in range(85):
#    numpais1.append(i+1)
#dfpais1 = pd.DataFrame(numpais, columns=['NumPais'])

#result1 = pd.concat([number1, dia1, dfpais], axis=1)

#numero2=[]
#for i in range(85):
#    numero2.append(2)
#number2= pd.DataFrame(numero2, columns=['Dia'])
#dia2 = coronapaises[['Paises', 'Casos2', 'Muertes2']]
#dia2.columns = ['Paises', 'Casos', 'Muertes']
#result2 = pd.concat([number2, dia2], axis=1)
#result2.head()

#frames = [result1, result2]
#result = pd.con

# %%
columns_names = ['Dia', 'Paises', 'Casos', 'Muertes']
df = pd.DataFrame(columns=columns_names)
lista =[]

# %%
for j in range(30):
    dummy='numero'+str(j+1)
    dummy=[]
    for i in range(85):
        dummy.append(j+1)
    dummy2='number'+str(j+1)
    dummy2= pd.DataFrame(dummy, columns=['Dia'])
    
    dummy3='dia'+str(j+1)
    dummy3 = coronapaises[['Paises', 'Casos'+str(j+1), 'Muertes'+str(j+1)]]
    dummy3.columns = ['Paises', 'Casos', 'Muertes']
    
    dummy4='numpais'+str(j+1)
    dummy4=[]
    for i in range(85):
        dummy4.append(i+1)
    dummy5 = 'dfpais'+str(j+1)
    dummy5= pd.DataFrame(dummy4, columns=['NumPais'])
    
    dummy6 = 'result'+str(j+1)
    dummy6= pd.concat([dummy2, dummy3,dummy5], axis=1)
    lista.append(dummy6)
df = pd.concat(lista)

# %%
df.head()
# Out:
#    Dia             Paises  Casos  Muertes  NumPais
# 0    1  Republic of Korea   16.0      0.0        1
# 1    1              Japan   20.0      0.0        2
# 2    1          Singapore   18.0      0.0        3
# 3    1           Malaysia   10.0      0.0        4
# 4    1          Australia   12.0      0.0        5

# %%
# %matplotlib notebook
start_time = 1.00
end_time = 30.00

fig, ax = plt.subplots(1,1)
plt.subplots_adjust(bottom=0.25)
sax = plt.axes([0.25, 0.1, 0.65, 0.03])
slide = Slider(sax, '04/02 al 05/03', start_time, end_time, valinit=start_time)


act_data = df.loc[df['Dia'] == float(int(start_time))]
s, = ax.plot(act_data.NumPais, act_data.Casos, 'o', color='green')
ax.set_title('Casos de Coronavirus en el mundo en 2020')
ax.set_ylabel('Número de casos')
ax.set_xlabel('Países')

def update(Dia):
    act_data = df.loc[df['Dia'] == float(int(Dia))]
    X = act_data.NumPais
    Y = act_data.Casos

    #Actualizar datos basados en el slider
    s.set_xdata(X)
    s.set_ydata(Y)

    #Reiniciar los limites de los ejes
    ax.set_xlim([X.min()*0.9,X.max()*1.1])
    ax.set_ylim([Y.min()*0.9,Y.max()*1.1])

    fig.canvas.draw()

slide.on_changed(update)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
start_time = 1.00
end_time = 30.00

fig, ax = plt.subplots(1,1)
plt.subplots_adjust(bottom=0.25)
sax = plt.axes([0.25, 0.1, 0.65, 0.03])
slide = Slider(sax, 'Del 04/02 al 05/03', start_time, end_time, valinit=start_time)

act_data = df.loc[df['Dia'] == float(int(start_time))]
s, = ax.plot(act_data.NumPais, act_data.Muertes, 'o', color='red')
ax.set_title(' Muertes a casusa del Coronavirus en el mundo 2020')
ax.set_ylabel('Número de muertes')
ax.set_xlabel('Países')

def update(Dia):
    act_data = df.loc[df['Dia'] == float(int(Dia))]
    X = act_data.NumPais
    Y = act_data.Muertes

    #Actualizar datos basados en el slider
    s.set_xdata(X)
    s.set_ydata(Y)

    #Reiniciar los limites de los ejes
    ax.set_xlim([X.min()*0.9,X.max()*1.1])
    ax.set_ylim([Y.min()*0.9,Y.max()*1.1])

    fig.canvas.draw()


slide.on_changed(update)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
dfchina = pd.read_csv('china.csv', delimiter=',')
dfchina.head()
# Out:
#    Dia  Casos  Muertes
# 0    1  20417      425
# 1    2  24363      491
# 2    3  28060      564
# 3    4  31211      637
# 4    5  34598      723

# %%
dfc = dfchina[['Casos']]
dfm = dfchina[['Muertes']]

# %%
# %matplotlib inline
df1 = pd.concat([dfc,dfm], axis = 1)
def multiplot(Categoria):
    opts = df1.columns.values
    df1.loc[:, Categoria].plot(marker='o', title='Casos/muertes Coronavirus en China 2020', c='red')
    plt.set_xlabel=('ola')

interactive_plot = interactive(multiplot, Categoria=['Casos', 'Muertes'])
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(Dropdown(description='Categoria', options=('Casos', 'Muertes'), value='Casos'), Output(l…
